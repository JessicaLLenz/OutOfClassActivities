# %%
import polars as pl
import polars.selectors as cs
from glob import glob
from toolz import pipe
from functools import reduce
from operator import add, mul

# %%
# Remove the bad file (See below)
# !rm ./data/uber/uber-bad.csv
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Column exploration using `polars` tables.
#
# In this lecture, we will explore how to use `polars` tables to explore the columns across many files. This will help us find and fix problems with the naming and order of columns across the files.
#
# **Basic procedure:** We want to make a column summary table that shows which columns are present in each file. We will do this by:
# 1. Use `glob` to find all files matching a pattern.
# 1. Read in each file as a list of `polars` tables.
# 2. Stack all columns and aggregate to find unique columns and their counts.
# 3. Create an columns containing the literal value of `1`.
# 4. Use a reduction to join all the tables together on the column names.
# 5. Replace missing values with `0`.
# 6. Explore the resulting table to find problems, e.g. columns that are not in all files, columns with different capitalization, etc.

# %% [markdown]
# ### Example - Exploring the columns in Uber data files

# %% [markdown]
# #### Step 1: Use `glob` to find all files matching a pattern

# %%
(uber_paths :=
 glob('./data/uber/uber/*.csv')
)
# Out:
# ['./data/uber/uber\\uber-raw-data-apr14-sample.csv',
#  './data/uber/uber\\uber-raw-data-aug14-sample.csv',
#  './data/uber/uber\\uber-raw-data-jul14-sample.csv',
#  './data/uber/uber\\uber-raw-data-jun14-sample.csv',
#  './data/uber/uber\\uber-raw-data-may14-sample.csv',
#  './data/uber/uber\\uber-raw-data-sep14-sample.csv']

# %% [markdown]
# #### Step 2: Read and process each file
#
# **Procedure:**
# 1. Read one row from each file.
# 2. Add a new column containing the file name.
# 3. Use `unpivot` to stack all columns except the file name.
# 4. Drop the values column.
# 5. Add a new column containing the literal value of `1`.
# 6. Use `pivot` to unstack the table so that each file is a column.

# %%
(uber_tables :=
 [pl.read_csv(p)
    .head(1)
    .with_columns(file = pl.lit(p.replace('\\','/').split('/')[-1]))
    .unpivot(index='file', variable_name='Column')
    .drop('value')
    .with_columns(pl.lit(1).alias('ones'))
    .pivot(index = 'Column', columns='file', values='ones')
  for p in uber_paths
  ]
)
# Out:
# C:\Users\rt2332in\AppData\Local\Temp\ipykernel_15144\3967019297.py:8: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   .pivot(index = 'Column', columns='file', values='ones')
# [shape: (4, 2)
#  ┌───────────┬────────────────────────────────┐
#  │ Column    ┆ uber-raw-data-apr14-sample.csv │
#  │ ---       ┆ ---                            │
#  │ str       ┆ i32                            │
#  ╞═══════════╪════════════════════════════════╡
#  │ Date/Time ┆ 1                              │
#  │ Lat       ┆ 1                              │
#  │ Lon       ┆ 1                              │
#  │ Base      ┆ 1                              │
#  └───────────┴────────────────────────────────┘,
#  shape: (4, 2)
#  ┌───────────┬────────────────────────────────┐
#  │ Column    ┆ uber-raw-data-aug14-sample.csv │
#  │ ---       ┆ ---                            │
#  │ str       ┆ i32                            │
#  ╞═══════════╪════════════════════════════════╡
#  │ Date/Time ┆ 1                              │
#  │ Lat       ┆ 1                              │
#  │ Lon       ┆ 1                              │
#  │ Base      ┆ 1                              │
#  └───────────┴────────────────────────────────┘,
#  shape: (4, 2)
#  ┌───────────┬────────────────────────────────┐
#  │ Column    ┆ uber-raw-data-jul14-sample.csv │
#  │ ---       ┆ ---                            │
#  │ str       ┆ i32                            │
#  ╞═══════════╪════════════════════════════════╡
#  │ Date/Time ┆ 1                              │
#  │ Lat       ┆ 1                              │
#  │ Lon       ┆ 1                              │
#  │ Base      ┆ 1                              │
#  └───────────┴────────────────────────────────┘,
#  shape: (4, 2)
#  ┌───────────┬────────────────────────────────┐
#  │ Column    ┆ uber-raw-data-jun14-sample.csv │
#  │ ---       ┆ ---                            │
#  │ str       ┆ i32                            │
#  ╞═══════════╪════════════════════════════════╡
#  │ Date/Time ┆ 1                              │
#  │ Lat       ┆ 1                              │
#  │ Lon       ┆ 1                              │
#  │ Base      ┆ 1                              │
#  └───────────┴────────────────────────────────┘,
#  shape: (4, 2)
#  ┌───────────┬────────────────────────────────┐
#  │ Column    ┆ uber-raw-data-may14-sample.csv │
#  │ ---       ┆ ---                            │
#  │ str       ┆ i32                            │
#  ╞═══════════╪════════════════════════════════╡
#  │ Date/Time ┆ 1                              │
#  │ Lat       ┆ 1                              │
#  │ Lon       ┆ 1                              │
#  │ Base      ┆ 1                              │
#  └───────────┴────────────────────────────────┘,
#  shape: (4, 2)
#  ┌───────────┬────────────────────────────────┐
#  │ Column    ┆ uber-raw-data-sep14-sample.csv │
#  │ ---       ┆ ---                            │
#  │ str       ┆ i32                            │
#  ╞═══════════╪════════════════════════════════╡
#  │ Date/Time ┆ 1                              │
#  │ Lat       ┆ 1                              │
#  │ Lon       ┆ 1                              │
#  │ Base      ┆ 1                              │
#  └───────────┴────────────────────────────────┘]

# %% [markdown]
# #### Step 3: Combine all the processed tables into a single table

# %%
df1 = pl.DataFrame({'Column': ['a', 'b'],
                    'file1.csv':2*[1]})
df2 = pl.DataFrame({'Column': ['a', 'c'],
                    'file2.csv':2*[1]})

# %%
(df1.join(df2, 
          on='Column', 
          how = 'outer', 
          suffix = '_right',
          )
    .with_columns(Column = pl.coalesce('Column', 'Column_right'))
    .drop('Column_right')
)
# Out:
# C:\Users\rt2332in\AppData\Local\Temp\ipykernel_15144\297218877.py:1: DeprecationWarning: use of `how='outer'` should be replaced with `how='full'`.
# (Deprecated in version 0.20.29)
#   (df1.join(df2,
# shape: (3, 3)
# ┌────────┬───────────┬───────────┐
# │ Column ┆ file1.csv ┆ file2.csv │
# │ ---    ┆ ---       ┆ ---       │
# │ str    ┆ i64       ┆ i64       │
# ╞════════╪═══════════╪═══════════╡
# │ a      ┆ 1         ┆ 1         │
# │ c      ┆ null      ┆ 1         │
# │ b      ┆ 1         ┆ null      │
# └────────┴───────────┴───────────┘

# %%
join_next = lambda df1, df2: (df1.join(df2, 
                                       on='Column', 
                                       how = 'outer', 
                                       suffix = '_right')
                                 .with_columns(Column = pl.coalesce('Column', 'Column_right'))
                                 .drop('Column_right')
                             )

(combined_tables :=
 reduce(join_next, uber_tables)
 .fill_null(0)
 .sort('Column') # Should help find similar names/spellings/cases
)
# Out:
# C:\Users\rt2332in\AppData\Local\Temp\ipykernel_15144\3979226099.py:1: DeprecationWarning: use of `how='outer'` should be replaced with `how='full'`.
# (Deprecated in version 0.20.29)
#   join_next = lambda df1, df2: (df1.join(df2,
# shape: (4, 7)
# ┌───────────┬──────────────┬──────────────┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ Column    ┆ uber-raw-dat ┆ uber-raw-dat ┆ uber-raw-dat ┆ uber-raw-da ┆ uber-raw-da ┆ uber-raw-da │
# │ ---       ┆ a-apr14-samp ┆ a-aug14-samp ┆ a-jul14-samp ┆ ta-jun14-sa ┆ ta-may14-sa ┆ ta-sep14-sa │
# │ str       ┆ le.csv       ┆ le.csv       ┆ le.csv       ┆ mple.csv    ┆ mple.csv    ┆ mple.csv    │
# │           ┆ ---          ┆ ---          ┆ ---          ┆ ---         ┆ ---         ┆ ---         │
# │           ┆ i32          ┆ i32          ┆ i32          ┆ i32         ┆ i32         ┆ i32         │
# ╞═══════════╪══════════════╪══════════════╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ Base      ┆ 1            ┆ 1            ┆ 1            ┆ 1           ┆ 1           ┆ 1           │
# │ Date/Time ┆ 1            ┆ 1            ┆ 1            ┆ 1           ┆ 1           ┆ 1           │
# │ Lat       ┆ 1            ┆ 1            ┆ 1            ┆ 1           ┆ 1           ┆ 1           │
# │ Lon       ┆ 1            ┆ 1            ┆ 1            ┆ 1           ┆ 1           ┆ 1           │
# └───────────┴──────────────┴──────────────┴──────────────┴─────────────┴─────────────┴─────────────┘

# %% [markdown]
# #### Step 5: Explore the combined table

# %%
(combined_tables :=
 combined_tables
 .with_columns(all = pl.reduce(mul, cs.starts_with('uber')),       # Multiple 1/0 columns <==> AND
               count = pl.reduce(add, cs.starts_with('uber')),
               )
)
# Out:
# shape: (4, 9)
# ┌───────────┬─────────────┬─────────────┬─────────────┬───┬─────────────┬────────────┬─────┬───────┐
# │ Column    ┆ uber-raw-da ┆ uber-raw-da ┆ uber-raw-da ┆ … ┆ uber-raw-da ┆ uber-raw-d ┆ all ┆ count │
# │ ---       ┆ ta-apr14-sa ┆ ta-aug14-sa ┆ ta-jul14-sa ┆   ┆ ta-may14-sa ┆ ata-sep14- ┆ --- ┆ ---   │
# │ str       ┆ mple.csv    ┆ mple.csv    ┆ mple.csv    ┆   ┆ mple.csv    ┆ sample.csv ┆ i32 ┆ i32   │
# │           ┆ ---         ┆ ---         ┆ ---         ┆   ┆ ---         ┆ ---        ┆     ┆       │
# │           ┆ i32         ┆ i32         ┆ i32         ┆   ┆ i32         ┆ i32        ┆     ┆       │
# ╞═══════════╪═════════════╪═════════════╪═════════════╪═══╪═════════════╪════════════╪═════╪═══════╡
# │ Base      ┆ 1           ┆ 1           ┆ 1           ┆ … ┆ 1           ┆ 1          ┆ 1   ┆ 6     │
# │ Date/Time ┆ 1           ┆ 1           ┆ 1           ┆ … ┆ 1           ┆ 1          ┆ 1   ┆ 6     │
# │ Lat       ┆ 1           ┆ 1           ┆ 1           ┆ … ┆ 1           ┆ 1          ┆ 1   ┆ 6     │
# │ Lon       ┆ 1           ┆ 1           ┆ 1           ┆ … ┆ 1           ┆ 1          ┆ 1   ┆ 6     │
# └───────────┴─────────────┴─────────────┴─────────────┴───┴─────────────┴────────────┴─────┴───────┘

# %% [markdown]
# ### Putting it all together

# %%
join_next = lambda df1, df2: (df1.join(df2, on='Column', how = 'full', suffix = '_right')
                                 .with_columns(Column = pl.coalesce('Column', 'Column_right'))
                                 .drop('Column_right')
                             )


(uber_column_summary :=
 pipe(glob('./data/uber/uber/*.csv'),
     lambda L: [pl.read_csv(p)
                  .with_columns(file = pl.lit(p.replace('\\','/').split('/')[-1]))
                  .head(1) 
                  .unpivot(index='file', 
                           variable_name='Column')
                  .drop('value')
                  .with_columns(pl.lit(1).alias('ones'))
                  .pivot(index = 'Column', 
                         on='file', 
                         values='ones') 
                for p in L 
                ],
     lambda L: reduce(join_next, L).sort('Column').fill_null(0),
     lambda df: df.with_columns(all = pl.reduce(mul, cs.starts_with('uber')), 
                                count = pl.reduce(add, cs.starts_with('uber'))
                               ),
     )
)
# Out:
# shape: (4, 9)
# ┌───────────┬─────────────┬─────────────┬─────────────┬───┬─────────────┬────────────┬─────┬───────┐
# │ Column    ┆ uber-raw-da ┆ uber-raw-da ┆ uber-raw-da ┆ … ┆ uber-raw-da ┆ uber-raw-d ┆ all ┆ count │
# │ ---       ┆ ta-apr14-sa ┆ ta-aug14-sa ┆ ta-jul14-sa ┆   ┆ ta-may14-sa ┆ ata-sep14- ┆ --- ┆ ---   │
# │ str       ┆ mple.csv    ┆ mple.csv    ┆ mple.csv    ┆   ┆ mple.csv    ┆ sample.csv ┆ i32 ┆ i32   │
# │           ┆ ---         ┆ ---         ┆ ---         ┆   ┆ ---         ┆ ---        ┆     ┆       │
# │           ┆ i32         ┆ i32         ┆ i32         ┆   ┆ i32         ┆ i32        ┆     ┆       │
# ╞═══════════╪═════════════╪═════════════╪═════════════╪═══╪═════════════╪════════════╪═════╪═══════╡
# │ Base      ┆ 1           ┆ 1           ┆ 1           ┆ … ┆ 1           ┆ 1          ┆ 1   ┆ 6     │
# │ Date/Time ┆ 1           ┆ 1           ┆ 1           ┆ … ┆ 1           ┆ 1          ┆ 1   ┆ 6     │
# │ Lat       ┆ 1           ┆ 1           ┆ 1           ┆ … ┆ 1           ┆ 1          ┆ 1   ┆ 6     │
# │ Lon       ┆ 1           ┆ 1           ┆ 1           ┆ … ┆ 1           ┆ 1          ┆ 1   ┆ 6     │
# └───────────┴─────────────┴─────────────┴─────────────┴───┴─────────────┴────────────┴─────┴───────┘

# %% [markdown]
# #### Look for missing columns

# %%
(uber_column_summary
 .filter(pl.col('all') == 0)
)
# Out:
# shape: (0, 9)
# ┌────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────┬───────┐
# │ Column ┆ uber-raw-dat ┆ uber-raw-dat ┆ uber-raw-da ┆ … ┆ uber-raw-da ┆ uber-raw-da ┆ all ┆ count │
# │ ---    ┆ a-apr14-samp ┆ a-aug14-samp ┆ ta-jul14-sa ┆   ┆ ta-may14-sa ┆ ta-sep14-sa ┆ --- ┆ ---   │
# │ str    ┆ le.csv       ┆ le.csv       ┆ mple.csv    ┆   ┆ mple.csv    ┆ mple.csv    ┆ i32 ┆ i32   │
# │        ┆ ---          ┆ ---          ┆ ---         ┆   ┆ ---         ┆ ---         ┆     ┆       │
# │        ┆ i32          ┆ i32          ┆ i32         ┆   ┆ i32         ┆ i32         ┆     ┆       │
# ╞════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════╪═══════╡
# └────────┴──────────────┴──────────────┴─────────────┴───┴─────────────┴─────────────┴─────┴───────┘

# %% [markdown]
# #### Find columns that are not in all files with a count

# %%
(uber_column_summary
 .filter(pl.col('count') != pl.col('count').max())
)
# Out:
# shape: (0, 9)
# ┌────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────┬───────┐
# │ Column ┆ uber-raw-dat ┆ uber-raw-dat ┆ uber-raw-da ┆ … ┆ uber-raw-da ┆ uber-raw-da ┆ all ┆ count │
# │ ---    ┆ a-apr14-samp ┆ a-aug14-samp ┆ ta-jul14-sa ┆   ┆ ta-may14-sa ┆ ta-sep14-sa ┆ --- ┆ ---   │
# │ str    ┆ le.csv       ┆ le.csv       ┆ mple.csv    ┆   ┆ mple.csv    ┆ mple.csv    ┆ i32 ┆ i32   │
# │        ┆ ---          ┆ ---          ┆ ---         ┆   ┆ ---         ┆ ---         ┆     ┆       │
# │        ┆ i32          ┆ i32          ┆ i32         ┆   ┆ i32         ┆ i32         ┆     ┆       │
# ╞════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════╪═══════╡
# └────────┴──────────────┴──────────────┴─────────────┴───┴─────────────┴─────────────┴─────┴───────┘

# %% [markdown]
# ## What if things go wrong?
#
# Now let's manufacture some problems with the files and see how we can use our column exploration table to find and fix them.

# %%
f = uber_paths[0] 
original_columns = (pl.read_csv(f).head(1).columns)

(pl.read_csv(f)
   .rename({c:c.upper() for c in original_columns})
   .write_csv(f'data/uber/uber-bad.csv')
)

# %% [markdown]
# #### Redo the column summary table to see what has changed.

# %%
join_next = lambda df1, df2: (df1.join(df2, on='Column', how = 'full', suffix = '_right')
                                 .with_columns(Column = pl.coalesce('Column', 'Column_right'))
                                 .drop('Column_right')
                             )


(uber_column_summary :=
 pipe(glob('./data/uber/*.csv'),
     lambda L: [pl.read_csv(p)
                  .with_columns(file = pl.lit(p.split('/')[-1]))
                  .head(1) 
                  .unpivot(index='file', 
                           variable_name='Column')
                  .drop('value')
                  .with_columns(pl.lit(1).alias('ones'))
                  .pivot(index = 'Column', 
                         on='file', 
                         values='ones') 
                for p in L 
                ],
     lambda L: reduce(join_next, L).sort('Column').fill_null(0),
     lambda df: df.with_columns(all = pl.reduce(mul, cs.starts_with('uber')), 
                                count = pl.reduce(add, cs.starts_with('uber'))
                               ),
     )
)
# Out:
# shape: (4, 4)
# ┌───────────┬───────────────────┬─────┬───────┐
# │ Column    ┆ uber\uber-bad.csv ┆ all ┆ count │
# │ ---       ┆ ---               ┆ --- ┆ ---   │
# │ str       ┆ i32               ┆ i32 ┆ i32   │
# ╞═══════════╪═══════════════════╪═════╪═══════╡
# │ BASE      ┆ 1                 ┆ 1   ┆ 1     │
# │ DATE/TIME ┆ 1                 ┆ 1   ┆ 1     │
# │ LAT       ┆ 1                 ┆ 1   ┆ 1     │
# │ LON       ┆ 1                 ┆ 1   ┆ 1     │
# └───────────┴───────────────────┴─────┴───────┘

# %% [markdown]
# #### Look for missing columns

# %%
(uber_column_summary
 .filter(pl.col('all') == 0)
)
# Out:
# shape: (0, 4)
# ┌────────┬───────────────────┬─────┬───────┐
# │ Column ┆ uber\uber-bad.csv ┆ all ┆ count │
# │ ---    ┆ ---               ┆ --- ┆ ---   │
# │ str    ┆ i32               ┆ i32 ┆ i32   │
# ╞════════╪═══════════════════╪═════╪═══════╡
# └────────┴───────────────────┴─────┴───────┘

# %% [markdown]
# #### Find columns that are not in all files with a count

# %%
(uber_column_summary
 .filter(pl.col('count') != pl.col('count').max())
)
# Out:
# shape: (0, 4)
# ┌────────┬───────────────────┬─────┬───────┐
# │ Column ┆ uber\uber-bad.csv ┆ all ┆ count │
# │ ---    ┆ ---               ┆ --- ┆ ---   │
# │ str    ┆ i32               ┆ i32 ┆ i32   │
# ╞════════╪═══════════════════╪═════╪═══════╡
# └────────┴───────────────────┴─────┴───────┘

# %% [markdown]
# ## Fixing problems
#
# **Basic procedure:** To fix problems with column names, we will:
# 1. Read all original columns into a dict of dict.  The outer dict will have a key mapping to the file name and a value mapping to a dict of column names for that file.  The inner dict will have a key mapping to the original column name and a value mapping to the original column name.
# 2. These inner dict are meant to be used to rename columns.  We will use a function to apply the following transformations:
#    - Renaming columns
#    - Changing the case of columns
# 3. Additionally, we may need use `select` to reorder columns and add/remove missing columns.
#    - Reordering columns
#    - Adding/removing missing columns
#    - Recasting columns to a specific data type
#
#
# **Note.** This is a manual process that requires knowledge of the data and the desired column names and order, so solutions will vary.

# %%
(uber_paths :=
 glob('./data/uber/*.csv')
)
# Out:
# ['./data/uber\\uber-bad.csv']

# %%
(original_columns :=
 {p:{col: col
     for col in 
     pl.read_csv(p).columns
    }
  for p in uber_paths
 }

)
# Out:
# {'./data/uber\\uber-bad.csv': {'DATE/TIME': 'DATE/TIME',
#   'LAT': 'LAT',
#   'LON': 'LON',
#   'BASE': 'BASE'}}

# %%
(fixed_columns :=
 {**original_columns, 
  './data/uber/uber-bad.csv':{col:col.title() 
                             for col in original_columns['./data/uber\\uber-bad.csv']
                             },
}
)
# Out:
# {'./data/uber\\uber-bad.csv': {'DATE/TIME': 'DATE/TIME',
#   'LAT': 'LAT',
#   'LON': 'LON',
#   'BASE': 'BASE'},
#  './data/uber/uber-bad.csv': {'DATE/TIME': 'Date/Time',
#   'LAT': 'Lat',
#   'LON': 'Lon',
#   'BASE': 'Base'}}

# %% [markdown]
# #### Make a type and order specification for the correct columns (Brute force)

# %%
(col_and_types := {'Date/Time': pl.String(),
                   'Lat': pl.Float64(),
                   'Lon': pl.Float64(),
                   'Base': pl.String(),
                  }
)
# Out:
# {'Date/Time': String, 'Lat': Float64, 'Lon': Float64, 'Base': String}

# %% [markdown]
# #### Make a type and order specification (programmatic)

# %%
(example_correct_table := pl.read_csv(uber_paths[0]).head()
)
# Out:
# shape: (5, 4)
# ┌────────────────────┬─────────┬──────────┬────────┐
# │ DATE/TIME          ┆ LAT     ┆ LON      ┆ BASE   │
# │ ---                ┆ ---     ┆ ---      ┆ ---    │
# │ str                ┆ f64     ┆ f64      ┆ str    │
# ╞════════════════════╪═════════╪══════════╪════════╡
# │ 4/18/2014 21:38:00 ┆ 40.7359 ┆ -73.9852 ┆ B02682 │
# │ 4/23/2014 15:19:00 ┆ 40.7642 ┆ -73.9543 ┆ B02598 │
# │ 4/10/2014 7:15:00  ┆ 40.7138 ┆ -74.0103 ┆ B02598 │
# │ 4/11/2014 15:23:00 ┆ 40.7847 ┆ -73.9698 ┆ B02682 │
# │ 4/7/2014 17:26:00  ┆ 40.646  ┆ -73.7767 ┆ B02598 │
# └────────────────────┴─────────┴──────────┴────────┘

# %%
(str_columns := example_correct_table.select(cs.string()).columns
)
# Out:
# ['DATE/TIME', 'BASE']

# %%
(float_columns := example_correct_table.select(cs.float()).columns
)
# Out:
# ['LAT', 'LON']

# %%
(col_and_types := {c: pl.String() for c in str_columns
                  } |    # Merge operator
                  {c:pl.Float64() for c in float_columns
                  }
)
# Out:
# {'DATE/TIME': String, 'BASE': String, 'LAT': Float64, 'LON': Float64}

# %%
(uber_combined :=
 pl.concat([pl.read_csv(p)
              .rename(col_rename)
              .select([pl.col(c).cast(t) for c, t in col_and_types.items()])     # Reorder, remove, or recast columns as needed.
            for p, col_rename in fixed_columns.items()
           ]

))
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[76], line 4
#       1 (uber_combined :=
#       2  pl.concat([pl.read_csv(p)
#       3               .rename(col_rename)
# ----> 4               .select([pl.col(c).cast(t) for c, t in col_and_types.items()])     # Reorder, remove, or recast columns as needed.
#       5             for p, col_rename in fixed_columns.items()
#       6            ]
#       7
#       8 ))
#
# File ~\AppData\Local\anaconda3\envs\polars\Lib\site-packages\polars\dataframe\frame.py:9861, in DataFrame.select(self, *exprs, **named_exprs)
#    9777 """
#    9778 Select columns from this DataFrame.
#    9779
#    (...)   9854 └───────────┘
#    9855 """
#    9856 from polars.lazyframe.opt_flags import QueryOptFlags
#    9858 return (
#    9859     self.lazy()
#    9860     .select(*exprs, **named_exprs)
# -> 9861     .collect(optimizations=QueryOptFlags._eager())
#    9862 )
#
# File ~\AppData\Local\anaconda3\envs\polars\Lib\site-packages\polars\_utils\deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\polars\Lib\site-packages\polars\lazyframe\opt_flags.py:330, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     329 kwargs["optimizations"] = optflags
# --> 330 return function(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\polars\Lib\site-packages\polars\lazyframe\frame.py:2335, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2333 # Only for testing purposes
#    2334 callback = _kwargs.get("post_opt_callback", callback)
# -> 2335 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: unable to find column "DATE/TIME"; valid columns: ["Date/Time", "Lat", "Lon", "Base"]

# %%
# Remove the bad file (See below)
# !rm ./data/uber/uber-bad.csv
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## <font color = "red"> Exercise 4.3 </font>
#
# ### Task: Explore the column names in the City Bike data files
#
# The data folder contains a set of City Bike data files. Explore the column names in these files to find and fix any problems.  Provide a summary of the problems you found and how you fixed them.

# %%
# Your code here
(city_paths :=
 glob('./data/city_bike/city_bike/*.csv')
)
# Out:
# ['./data/city_bike/city_bike\\JC-201604-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-201605-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-201606-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-201607-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-201608-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-201609-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-20161-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-201610-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-201611-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-201612-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-20162-citibike-tripdata.csv',
#  './data/city_bike/city_bike\\JC-20163-citibike-tripdata.csv']

# %%
(bike_tables :=
 [pl.read_csv(p)
    .head(1)
    .with_columns(file = pl.lit(p.replace('\\','/').split('/')[-1]))
    .unpivot(index='file', variable_name='Column')
    .drop('value')
    .with_columns(pl.lit(1).alias('ones'))
    .pivot(index = 'Column', columns='file', values='ones')
  for p in city_paths
  ]
)
# Out:
# C:\Users\rt2332in\AppData\Local\Temp\ipykernel_15144\606572414.py:8: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   .pivot(index = 'Column', columns='file', values='ones')
# [shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201604-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201605-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201606-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201607-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201608-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201609-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬────────────────────────────────┐
#  │ Column                ┆ JC-20161-citibike-tripdata.csv │
#  │ ---                   ┆ ---                            │
#  │ str                   ┆ i32                            │
#  ╞═══════════════════════╪════════════════════════════════╡
#  │ Trip Duration         ┆ 1                              │
#  │ Start Time            ┆ 1                              │
#  │ Stop Time             ┆ 1                              │
#  │ Start Station ID      ┆ 1                              │
#  │ Start Station Name    ┆ 1                              │
#  │ …                     ┆ …                              │
#  │ End Station Longitude ┆ 1                              │
#  │ Bike ID               ┆ 1                              │
#  │ User Type             ┆ 1                              │
#  │ Birth Year            ┆ 1                              │
#  │ Gender                ┆ 1                              │
#  └───────────────────────┴────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201610-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201611-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬─────────────────────────────────┐
#  │ Column                ┆ JC-201612-citibike-tripdata.cs… │
#  │ ---                   ┆ ---                             │
#  │ str                   ┆ i32                             │
#  ╞═══════════════════════╪═════════════════════════════════╡
#  │ Trip Duration         ┆ 1                               │
#  │ Start Time            ┆ 1                               │
#  │ Stop Time             ┆ 1                               │
#  │ Start Station ID      ┆ 1                               │
#  │ Start Station Name    ┆ 1                               │
#  │ …                     ┆ …                               │
#  │ End Station Longitude ┆ 1                               │
#  │ Bike ID               ┆ 1                               │
#  │ User Type             ┆ 1                               │
#  │ Birth Year            ┆ 1                               │
#  │ Gender                ┆ 1                               │
#  └───────────────────────┴─────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬────────────────────────────────┐
#  │ Column                ┆ JC-20162-citibike-tripdata.csv │
#  │ ---                   ┆ ---                            │
#  │ str                   ┆ i32                            │
#  ╞═══════════════════════╪════════════════════════════════╡
#  │ Trip Duration         ┆ 1                              │
#  │ Start Time            ┆ 1                              │
#  │ Stop Time             ┆ 1                              │
#  │ Start Station ID      ┆ 1                              │
#  │ Start Station Name    ┆ 1                              │
#  │ …                     ┆ …                              │
#  │ End Station Longitude ┆ 1                              │
#  │ Bike ID               ┆ 1                              │
#  │ User Type             ┆ 1                              │
#  │ Birth Year            ┆ 1                              │
#  │ Gender                ┆ 1                              │
#  └───────────────────────┴────────────────────────────────┘,
#  shape: (15, 2)
#  ┌───────────────────────┬────────────────────────────────┐
#  │ Column                ┆ JC-20163-citibike-tripdata.csv │
#  │ ---                   ┆ ---                            │
#  │ str                   ┆ i32                            │
#  ╞═══════════════════════╪════════════════════════════════╡
#  │ Trip Duration         ┆ 1                              │
#  │ Start Time            ┆ 1                              │
#  │ Stop Time             ┆ 1                              │
#  │ Start Station ID      ┆ 1                              │
#  │ Start Station Name    ┆ 1                              │
#  │ …                     ┆ …                              │
#  │ End Station Longitude ┆ 1                              │
#  │ Bike ID               ┆ 1                              │
#  │ User Type             ┆ 1                              │
#  │ Birth Year            ┆ 1                              │
#  │ Gender                ┆ 1                              │
#  └───────────────────────┴────────────────────────────────┘]

# %%
pl.Config.set_tbl_rows(32)
# Out:
# polars.config.Config

# %%
join_next = lambda df1, df2: (df1.join(df2, 
                                       on='Column', 
                                       how = 'outer', 
                                       suffix = '_right')
                                 .with_columns(Column = pl.coalesce('Column', 'Column_right'))
                                 .drop('Column_right')
                             )

(combined_city :=
 reduce(join_next, bike_tables)
 .fill_null(0)
 .sort('Column') # Should help find similar names/spellings/cases
)
# Out:
# C:\Users\rt2332in\AppData\Local\Temp\ipykernel_15144\1362827198.py:1: DeprecationWarning: use of `how='outer'` should be replaced with `how='full'`.
# (Deprecated in version 0.20.29)
#   join_next = lambda df1, df2: (df1.join(df2,
# shape: (15, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Column    ┆ JC-201604 ┆ JC-201605 ┆ JC-201606 ┆ … ┆ JC-201611 ┆ JC-201612 ┆ JC-20162- ┆ JC-20163 │
# │ ---       ┆ -citibike ┆ -citibike ┆ -citibike ┆   ┆ -citibike ┆ -citibike ┆ citibike- ┆ -citibik │
# │ str       ┆ -tripdata ┆ -tripdata ┆ -tripdata ┆   ┆ -tripdata ┆ -tripdata ┆ tripdata. ┆ e-tripda │
# │           ┆ .cs…      ┆ .cs…      ┆ .cs…      ┆   ┆ .cs…      ┆ .cs…      ┆ csv       ┆ ta.csv   │
# │           ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ i32       ┆ i32       ┆ i32       ┆   ┆ i32       ┆ i32       ┆ i32       ┆ i32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bike ID   ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Birth     ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Year      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ End       ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Station   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ID        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ End       ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Station   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Latitude  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ End       ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Station   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Longitude ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ End       ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Station   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Name      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Gender    ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Start     ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Station   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ID        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Start     ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Station   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Latitude  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Start     ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Station   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Longitude ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Start     ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Station   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Name      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Start     ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Time      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Stop Time ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Trip      ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# │ Duration  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ User Type ┆ 1         ┆ 1         ┆ 1         ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 1        │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# <font color="orange">Your findings here.<font>
#
#     All of column names and data files match and the output of 1 shows this.
#     There are no 0's present in the combined data table
#     Had to configure to see the whole table and examine
